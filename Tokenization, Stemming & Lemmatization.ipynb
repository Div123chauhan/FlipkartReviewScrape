# %%
#Tokenization
import nltk,csv,numpy
nltk.download('punkt')
from nltk import sent_tokenize, word_tokenize, pos_tag
tokens=[]
reader = csv.reader(open('/content/FlipkartReview.csv', 'rU'), delimiter= ",",quotechar='|')
for line in reader:
    for field in line:
      tokens.append(word_tokenize(field))
print(tokens)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [['Title'], ['Review'], ['Rating'], ['Reviewer_name'], ['Very', 'Good'], ['``', 'I', 'ordered', 'this', 'mobile', 'for', 'my', 'sister', '.', '(', 'Online', 'classes', ')', 'It', 'works', 'well', 'for', 'day', 'to', 'day', 'use.Here', 'is', 'my', 'review', 'after', '10', 'days', 'of', 'use', ':', 'This', 'mobile', 'is', 'good', 'for', 'you'], ['but', 'if', 'you', 'are', 'planing', 'to', 'play', 'games', 'like', 'PUBG'], ['COD', 'ect', '.', 'Don', '’', 't', 'buy', 'this', 'Camera-', '3/5', 'camera', 'is', 'disappointing', 'both', 'front', 'and', 'back', '.', 'Also', 'the', 'front', 'camera', 'is', 'slow', 'as', 'well.Face', 'lock-', '3/5', 'average', 'one'], ['it', 'don', '’', 't', 'work', 'in', 'low', 'light', '.', 'Display-', '4/5', 'not', 'a', 'great', 'display', 'though', 'it', '’', 's', 'adjustable.Battery-', '4.5/5', 'it', 'has', 'good', 'battery', 'backup', '4000mah', 'but', 'a', '...', 'READ', 'MORE', "''"], ['4.3'], ['Flipkart', 'Customer'], ['Nice', 'product'], ['``', 'I', 'really', 'miss', 'the', 'finger', 'print', 'scanner', 'and', 'USB', 'type', 'c', 'port', '.', 'While', 'I', 'can', 'live', 'with', 'the', 'former'], ['the', 'later', 'is', 'a', 'crime', 'in', '2020.Apart', 'from', 'that'], ['everything', 'else', 'is', 'good', '.', 'I', 'really', 'liked', 'the', 'form', 'factor', '(', 'it', "'s", 'a', 'small', 'device', ')'], ['although', 'a', 'bit', 'slippery', '.', 'A', '5/5', 'for', 'the', 'display', '.', 'Battery', 'back-up', 'is', 'really', 'good', 'and', 'will', 'easily', 'last', '2', 'days', '(', 'with', 'medium', 'to', 'high', 'usage', ')', '.', 'Both', 'the', 'camera', 'works', 'well', 'in', 'outdoor', 'lighting', 'conditions', 'and', 'fails', 'to', 'perform', 'in', 'indoor', 'lighting', '.', 'Other', 'than', 'that'], ['the', 'camera', 'features', 'are', '...', 'READ', 'MORE', "''"], ['4'], ['Souvik', 'Das'], ['Perfect', 'product', '!'], ['I', 'ordered', 'this', 'phone', 'for', 'my', 'mom', '.', 'She', 'loves', 'it', '.', 'Samsung', 'has', 'really', 'made', 'a', 'good', 'handset', 'in', 'this', 'price', 'segment', '.', 'Lucky', 'to', 'grab', 'this', 'at', '8999', '.', 'Overall', 'experience', 'is', 'good', 'just', 'that', 'camera', 'quality', 'is', 'not', 'up', 'to', 'the', 'mark', 'as', 'far', 'as', 'brand', 'Samsung', 'is', 'concerned', '.', 'Also', 'I', 'am', 'happy', 'it', "'s", 'not', 'a', 'Chinese', 'product.READ', 'MORE'], ['4'], ['khusboo', 'kashyap'], ['Very', 'Good'], ['``', 'Bought', 'for', 'my', 'mom'], ['camera', 'quality', 'is', 'average'], ['there', 'is', 'a', 'small', 'heating', 'problem', 'but', 'its', 'not', 'a', 'big', 'deal'], ['Charging', 'is', 'slow', '.', 'video', 'quality', 'excellent'], ['good', 'battery', 'backup'], ['if', 'you', 'are', 'a', 'heavy', 'user', 'and', 'a', 'gamer', 'its', 'not', 'a', 'good', 'option', '.', 'Perfect', 'choice', 'for', 'elderly', 'and', 'regular', 'average', 'users'], ['you', 'can', 'get', 'better', 'phone', 'with', 'the', 'same', 'price', 'which', 'have', 'better', 'performance', 'but', 'almost', 'all', 'phones', 'are', 'from', 'chinese', 'brands', '.', 'All', 'cons', 'I', 'have', 'mentioned', 'above', 'is', 'nothing', 'if', 'we', 'compare', 'with', 'our', 'love', 'for', 'mother', 'india'], ['BOY', '...', 'READ', 'MORE', "''"], ['5'], ['Flipkart', 'Customer'], ['Awesome'], ['I', 'am', 'truly', 'satisfied', 'with', 'the', 'performance', 'of', 'the', 'phone.First', 'its', 'budget', 'phone', 'so', 'dont', 'expect', 'much', 'from', 'this', 'phone', '...', '.', 'coz', 'its', 'doesnt', 'have', 'feautures', 'like', 'finger', 'print', 'and', 'ctype', 'quick', 'charge', 'and', 'camera', 'quality', 'is', 'also', 'okay', 'but', 'not', 'bad', '...', '.', 'If', 'u', 'really', 'looking', 'for', 'small', 'screen', 'phones', 'its', 'the', 'best', 'one', 'with', 'snapdragon', '439', '(', '12nm', ')', 'processor', 'with', 'better', 'performance', 'than', 'mtk', 'and', 'exynos', '...', 'so', 'i', 'recommend', 'this', 'who', 'really', 'likes', 'small', 'screen', 'lovers', ...
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: DeprecationWarning: 'U' mode is deprecated

# %%
#Stemming
from nltk.stem.porter import *
p_stemmer = PorterStemmer()
for words in tokens:
  for word in words:
    print(word+' --> '+p_stemmer.stem(word))
# Out:
# Title --> titl
# Review --> review
# Rating --> rate
# Reviewer_name --> reviewer_nam
# Very --> veri
# Good --> good
# `` --> ``
# I --> I
# ordered --> order
# this --> thi
# mobile --> mobil
# for --> for
# my --> my
# sister --> sister
# . --> .
# ( --> (
# Online --> onlin
# classes --> class
# ) --> )
# It --> It
# works --> work
# well --> well
# for --> for
# day --> day
# to --> to
# day --> day
# use.Here --> use.her
# is --> is
# my --> my
# review --> review
# after --> after
# 10 --> 10
# days --> day
# of --> of
# use --> use
# : --> :
# This --> thi
# mobile --> mobil
# is --> is
# good --> good
# for --> for
# you --> you
# but --> but
# if --> if
# you --> you
# are --> are
# planing --> plane
# to --> to
# play --> play
# games --> game
# like --> like
# PUBG --> pubg
# COD --> cod
# ect --> ect
# . --> .
# Don --> don
# ’ --> ’
# t --> t
# buy --> buy
# this --> thi
# Camera- --> camera-
# 3/5 --> 3/5
# camera --> camera
# is --> is
# disappointing --> disappoint
# both --> both
# front --> front
# and --> and
# back --> back
# . --> .
# Also --> also
# the --> the
# front --> front
# camera --> camera
# is --> is
# slow --> slow
# as --> as
# well.Face --> well.fac
# lock- --> lock-
# 3/5 --> 3/5
# average --> averag
# one --> one
# it --> it
# don --> don
# ’ --> ’
# t --> t
# work --> work
# in --> in
# low --> low
# light --> light
# . --> .
# Display- --> display-
# 4/5 --> 4/5
# not --> not
# a --> a
# great --> great
# display --> display
# though --> though
# it --> it
# ’ --> ’
# s --> s
# adjustable.Battery- --> adjustable.battery-
# 4.5/5 --> 4.5/5
# it --> it
# has --> ha
# good --> good
# battery --> batteri
# backup --> backup
# 4000mah --> 4000mah
# but --> but
# a --> a
# ... --> ...
# READ --> read
# MORE --> more
# '' --> ''
# 4.3 --> 4.3
# Flipkart --> flipkart
# Customer --> custom
# Nice --> nice
# product --> product
# `` --> ``
# I --> I
# really --> realli
# miss --> miss
# the --> the
# finger --> finger
# print --> print
# scanner --> scanner
# and --> and
# USB --> usb
# type --> type
# c --> c
# port --> port
# . --> .
# While --> while
# I --> I
# can --> can
# live --> live
# with --> with
# the --> the
# former --> former
# the --> the
# later --> later
# is --> is
# a --> a
# crime --> crime
# in --> in
# 2020.Apart --> 2020.apart
# from --> from
# that --> that
# everything --> everyth
# else --> els
# is --> is
# good --> good
# . --> .
# I --> I
# really --> realli
# liked --> like
# the --> the
# form --> form
# factor --> factor
# ( --> (
# it --> it
# 's --> 's
# a --> a
# small --> small
# device --> devic
# ) --> )
# although --> although
# a --> a
# bit --> bit
# slippery --> slipperi
# . --> .
# A --> A
# 5/5 --> 5/5
# for --> for
# the --> the
# display --> display
# . --> .
# Battery --> batteri
# back-up --> back-up
# is --> is
# really --> realli
# good --> good
# and --> and
# will --> will
# easily --> easili
# last --> last
# 2 --> 2
# days --> day
# ( --> (
# with --> with
# medium --> medium
# to --> to
# high --> high
# usage --> usag
# ) --> )
# . --> .
# Both --> both
# the --> the
# camera --> camera
# works --> work
# well --> well
# in --> in
# outdoor --> outdoor
# lighting --> light
# conditions --> condit
# and --> and
# fails --> fail
# to --> to
# perform --> perform
# in --> in
# indoor --> indoor
# lighting --> light
# . --> .
# Other --> other
# than --> than
# that --> that
# the --> the
# camera --> camera
# features --> featur
# are --> are
# ... --> ...
# READ --> read
# MORE --> more
# '' --> ''
# 4 --> 4
# Souvik --> souvik
# Das --> da
# Perfect --> perfect
# product --> product
# ! --> !
# I --> I
# ordered --> order
# this --> thi
# phone --> phone
# for --> for
# my --> my
# mom --> mom
# . --> .
# She --> she
# loves --> love
# it --> it
# . --> .
# Samsung --> samsung
# has --> ha
# really --> realli
# made --> made
# a --> a
# good --> good
# handset --> handset
# in --> in
# this --> thi
# price --> price
# segment --> segment
# . --> .
# Lucky --> lucki
# to --> to
# grab --> grab
# this --> thi
# at --> at
# 8999 --> 8999
# . --> .
# Overall --> overal
# experience --> experi
# is --> is
# good --> good
# just --> just
# that --> that
# camera --> camera
# quality --> qualiti
# is --> is
# not --> not
# up --> up
# to --> to
# the --> the
# mark --> mark
# as --> as
# far --> far
# as --> as
# brand --> brand
# Samsung --> samsung
# is --> is
# concerned --> concern
# . --> .
# Also --> also
# I --> I
# am --> am
# happy --> happi
# it --> it
# 's --> 's
# not --> not
# a --> a
# Chinese --> chines
# product.READ --> product.read
# MORE --> more
# 4 --> 4
# khusboo --> khusboo
# kashyap --> kashyap
# Very --> veri
# Good --> good
# `` --> ``
# Bought --> bought
# for --> for
# my --> my
# mom --> mom
# camera --> camera
# quality --> qualiti
# is --> is
# average --> averag
# there --> there
# is --> is
# a --> a
# small --> small
# heating --> heat
# problem --> problem
# but --> but
# its --> it
# not --> not
# a --> a
# big --> big
# deal --> deal
# Charging --> charg
# is --> is
# slow --> slow
# . --> .
# video --> video
# quality --> qualiti
# excellent --> excel
# good --> good
# battery --> batteri
# backup --> backup
# if --> if
# you --> you
# are --> are
# a --> a
# heavy --> heavi
# user --> user
# and --> and
# a --> a
# gamer --> gamer
# its --> it
# not --> not
# a --> a
# good --> good
# option --> option
# . --> .
# Perfect --> perfect
# choice --> choic
# for --> for
# elderly --> elderli
# and --> and
# regular --> regular
# average --> averag
# users --> user
# you --> you
# can --> can
# get --> get
# better --> better
# phone --> phone
# with --> with
# the --> the
# same --> same
# price --> price
# which --> which
# have --> have
# better --> better
# performance --> perform
# but --> but
# almost --> almost
# all --> all
# phones --> phone
# are --> are
# from --> from
# chinese --> chines
# brands --> brand
# . --> .
# All --> all
# cons --> con
# I --> I
# have --> have
# mentioned --> mention
# above --> abov
# is --> is
# nothing --> noth
# if --> if
# we --> we
# compare --> compar
# with --> with
# our --> our
# love --> love
# for --> for
# mother --> mother
# india --> india
# BOY --> boy
# ... --> ...
# READ --> read
# MORE --> more
# '' --> ''
# 5 --> 5
# Flipkart --> flipkart
# Customer --> custom
# Awesome --> awesom
# I --> I
# am --> am
# truly --> truli
# satisfied --> satisfi
# with --> with
# the --> the
# performance --> perform
# of --> of
# the --> the
# phone.First --> phone.first
# its --> it
# budget --> budget
# phone --> phone
# so --> so
# dont --> dont
# expect --> expect
# much --> much
# from --> from
# this --> thi
# phone --> phone
# ... --> ...
# . --> .
# coz --> coz
# its --> it
# doesnt --> doesnt
# have --> have
# feautures --> feautur
# like --> like
# finger --> finger
# print --> print
# and --> and
# ctype --> ctype
# quick --> quick
# charge --> charg
# and --> and
# camera --> camera
# quality --> qualiti
# is --> is
# also --> also
# okay --> okay
# but --> but
# not --> not
# bad --> bad
# ... --> ...
# . --> .
# If --> If
# u --> u
# really --> realli
# looking --> look
# for --> for
# small --> small
# screen --> screen
# phones --> phone
# its --> it
# the --> the
# best --> best
# one --> one
# with --> with
# snapdragon --> snapdragon
# 439 --> 439
# ( --> (
# 12nm --> 12nm
# ) --> )
# processor --> processor
# with --> with
# better --> better
# performance --> perform
# than --> than
# mtk --> mtk
# and --> and
# exynos --> exyno
# ... --> ...
# so --> so
# i --> i
# recommend --> recommend
# this --> thi
# who --> who
# really --> realli
# likes --> like
# small --> small
# screen --> screen
# lovers --> lover
# and --> and
# who --> who
# doesnt --> doesnt
# like --> like
# extra --> extra
# added --> ad
# features --> featur
# ... --> ...
# Moreover --> moreov
# the --> the
# b --> b
# ... --> ...
# READ --> read
# MORE --> more
# 4 --> 4
# Thadiparthi --> thadiparthi
# Tharun --> tharun
# Excellent --> excel
# `` --> ``
# Worth --> worth
# for --> for
# money.But --> money.but
# no --> no
# fingerprint --> fingerprint
# sensor --> sensor
# . --> .
# But --> but
# has --> ha
# a --> a
# nice --> nice
# battery --> batteri
# capacity --> capac
# . --> .
# I --> I
# am --> am
# not --> not
# into --> into
# playing --> play
# games --> game
# as --> as
# I --> I
# am --> am
# a --> a
# 9th --> 9th
# student --> student
# . --> .
# But --> but
# nice --> nice
# phone --> phone
# with --> with
# no --> no
# lags --> lag
# and --> and
# hangs --> hang
# . --> .
# If --> If
# you --> you
# get --> get
# it --> it
# in --> in
# 9000 --> 9000
# or --> or
# below --> below
# just --> just
# go --> go
# for --> for
# it --> it
# guyz.READ --> guyz.read
# MORE --> more
# '' --> ''
# 5 --> 5
# Supriya --> supriya
# Todkar --> todkar
# Utterly --> utterli
# Disappointed --> disappoint
# `` --> ``
# Pros --> pro
# : --> :
# - --> -
# Battery --> batteri
# with --> with
# 4000mAh --> 4000mah
# -- --> --
# -- --> --
# 4.5/5Display --> 4.5/5display
# clarity --> clariti
# -- --> --
# -- --> --
# - --> -
# 3/5Cons --> 3/5con
# : --> :
# -1 --> -1
# ) --> )
# Pathetic/Worst --> pathetic/worst
# Camera --> camera
# Nokia --> nokia
# VGA --> vga
# camera --> camera
# is --> is
# much --> much
# better --> better
# wen --> wen
# u --> u
# zoom --> zoom
# . --> .
# I --> I
# believe --> believ
# Samsung --> samsung
# is --> is
# purposely --> purpos
# reducing --> reduc
# the --> the
# quality --> qualiti
# of --> of
# image --> imag
# thru --> thru
# there --> there
# World --> world
# 's --> 's
# worst --> worst
# camera --> camera
# app --> app
# . --> .
# With --> with
# this --> thi
# price --> price
# u --> u
# get --> get
# a --> a
# better --> better
# Camera --> camera
# quality --> qualiti
# phone --> phone
# . --> .
# I --> I
# tried --> tri
# to --> to
# return --> return
# but --> but
# Flipkart --> flipkart
# do --> do
# n't --> n't
# care --> care
# about --> about
# it --> it
# 's --> 's
# customers --> custom
# . --> .
# Best --> best
# thing --> thing
# to --> to
# do --> do
# is --> is
# Do --> Do
# n't --> n't
# even --> even
# think --> think
# abt --> abt
# taking --> take
# a --> a
# pic --> pic
# at --> at
# night --> night
# u --> u
# will --> will
# definitely --> definit
# throw --> throw
# the --> the
# phone --> phone
# . --> .
# -- --> --
# -- --> --
# -- --> --
# -- --> --
# -- --> --
# > --> >
# -5/52 --> -5/52
# ) --> )
# Video --> video
# is --> is
# just --> just
# OMG --> omg
# ... --> ...
# READ --> read
# MORE --> more
# '' --> ''
# 5 --> 5
# Deepak --> deepak
# R --> R
# Worth --> worth
# the --> the
# money --> money
# `` --> ``
# Its --> it
# been --> been
# more --> more
# than --> than
# a --> a
# week --> week
# since --> sinc
# i --> i
# bought --> bought
# this --> thi
# Mobile --> mobil
# phone --> phone
# for --> for
# my --> my
# Mother --> mother
# . --> .
# I --> I
# like --> like
# the --> the
# look --> look
# and --> and
# feel --> feel
# . --> .
# The --> the
# performance --> perform
# is --> is
# good --> good
# and --> and
# a --> a
# fine --> fine
# display --> display
# . --> .
# It --> It
# has --> ha
# a --> a
# decent --> decent
# battery --> batteri
# . --> .
# I --> I
# 'm --> 'm
# little --> littl
# bit --> bit
# disappointed --> disappoint
# with --> with
# the --> the
# camera --> camera
# . --> .
# Because --> becaus
# the --> the
# configuration --> configur
# mentioned --> mention
# for --> for
# rear --> rear
# camera --> camera
# is --> is
# 13 --> 13
# MP --> MP
# . --> .
# But --> but
# does --> doe
# n't --> n't
# look --> look
# like --> like
# that.. --> that..
# The --> the
# picture --> pictur
# quality --> qualiti
# is --> is
# low --> low
# and --> and
# not --> not
# up --> up
# to --> to
# the --> the
# mark --> mark
# of --> of
# 13MP.The --> 13mp.the
# speaker --> speaker
# is --> is
# pretty --> pretti
# average --> averag
# . --> .
# Not --> not
# so --> so
# effective --> effect
# when --> when
# we --> we
# put --> put
# the --> the
# call --> call
# on --> on
# loudspeaker.But --> loudspeaker.but
# over --> over
# all --> all
# i --> i
# suggest --> suggest
# this --> thi
# as --> as
# a --> a
# decent --> decent
# ch --> ch
# ... --> ...
# READ --> read
# MORE --> more
# '' --> ''
# 1 --> 1
# T.N.ARUN --> t.n.arun
# SUDHARSAN --> sudharsan
# Terrible --> terribl
# product --> product
# `` --> ``
# Hopeless --> hopeless
# product --> product
# from --> from
# SamsungAt --> samsungat
# this --> thi
# price --> price
# range --> rang
# there --> there
# are --> are
# much --> much
# better --> better
# options --> option
# available --> avail
# . --> .
# Please --> pleas
# dont --> dont
# waste --> wast
# you --> you
# money --> money
# on --> on
# this --> thi
# . --> .
# I --> I
# 'll --> 'll
# put --> put
# down --> down
# my --> my
# feedback --> feedback
# here --> here
# . --> .
# I --> I
# feel --> feel
# more --> more
# terrible --> terribl
# because --> becaus
# i --> i
# brought --> brought
# it --> it
# for --> for
# my --> my
# mother --> mother
# and --> and
# that --> that
# too --> too
# the --> the
# phone --> phone
# was --> wa
# on --> on
# Flash --> flash
# Sale --> sale
# . --> .
# ( --> (
# *facepalm* --> *facepalm*
# ) --> )
# CameraEven --> cameraeven
# local --> local
# phones --> phone
# these --> these
# days --> day
# have --> have
# good --> good
# camera --> camera
# performance --> perform
# but --> but
# this --> thi
# one --> one
# has --> ha
# below --> below
# standard --> standard
# camera --> camera
# . --> .
# There --> there
# is --> is
# grains --> grain
# in --> in
# the --> the
# screen --> screen
# when --> when
# you --> you
# click --> click
# moderate-low --> moderate-low
# light --> light
# pics --> pic
# . --> .
# Build --> build
# qualityIt --> qualityit
# has --> ha
# a --> a
# plastic --> plastic
# back --> back
# and --> and
# you --> you
# ... --> ...
# READ --> read
# MORE --> more
# '' --> ''
# 4 --> 4
# Abin --> abin
# Rajan --> rajan
# Nice --> nice
# product --> product
# The --> the
# camera --> camera
# quality --> qualiti
# is --> is
# poor --> poor
# compared --> compar
# to --> to
# other --> other
# brands --> brand
# available --> avail
# at --> at
# this --> thi
# range --> rang
# . --> .
# The --> the
# phone --> phone
# looks --> look
# decent --> decent
# and --> and
# is --> is
# easy --> easi
# to --> to
# use --> use
# single --> singl
# handed --> hand
# . --> .
# Display --> display
# is --> is
# one --> one
# of --> of
# the --> the
# major --> major
# highlight --> highlight
# . --> .
# Overall --> overal
# if --> if
# you --> you
# are --> are
# a --> a
# Samsung --> samsung
# lover --> lover
# and --> and
# looking --> look
# for --> for
# a --> a
# budget --> budget
# smartphone --> smartphon
# below --> below
# 10k --> 10k
# this --> thi
# one --> one
# is --> is
# for --> for
# you --> you
# . --> .
# They --> they
# are --> are
# not --> not
# providing --> provid
# transparent --> transpar
# case --> case
# in --> in
# the --> the
# box.READ --> box.read
# MORE --> more
# 1 --> 1
# Vignesh --> vignesh
# V --> V
# Gopal --> gopal

# %%
#Lemmatization
import spacy
nlp = spacy.load('en_core_web_sm')

def show_lemmas(text):
    for token in text:
        print(f'{token.text:{12}} {token.pos_:{6}} {token.lemma:<{22}} {token.lemma_}')

doc2 = nlp(u"i like the look and feel of this")

show_lemmas(doc2)
# Out:
# i            PRON   5097672513440128799    i
# like         VERB   18194338103975822726   like
# the          DET    7425985699627899538    the
# look         NOUN   16096726548953279178   look
# and          CCONJ  2283656566040971221    and
# feel         VERB   5741770584995928333    feel
# of           ADP    886050111519832510     of
# this         DET    1995909169258310477    this
